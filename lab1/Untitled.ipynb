# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
image = cv2.imread("ball.jpg")
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(1)
plt.subplot(1,2,1)
plt.imshow(image_rgb)
plt.subplot(1,2,2)
plt.imshow(image_gray,'gray')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
hist_bins = 256
hist_range = (0,256)
plt.figure(2)
plt.hist(image_gray.ravel(), bins=hist_bins),plt.gca().set_xlim(hist_range)
# Out:
# ((array([3.83000e+03, 1.38900e+03, 7.96000e+02, 6.09000e+02, 4.98000e+02,
#          3.75000e+02, 3.31000e+02, 3.39000e+02, 3.52000e+02, 2.62000e+02,
#          2.26000e+02, 2.57000e+02, 2.52000e+02, 2.61000e+02, 3.06000e+02,
#          3.29000e+02, 4.66000e+02, 4.21000e+02, 5.29000e+02, 5.42000e+02,
#          7.65000e+02, 1.03400e+03, 2.89900e+03, 1.16300e+03, 1.11600e+03,
#          3.99200e+03, 1.10900e+03, 9.14000e+02, 9.32000e+02, 1.17000e+03,
#          9.15000e+02, 7.77000e+02, 6.57000e+02, 6.76000e+02, 8.00000e+02,
#          6.76000e+02, 7.10000e+02, 7.54000e+02, 7.27000e+02, 2.04800e+03,
#          2.78600e+03, 1.68900e+03, 1.60000e+03, 1.59000e+03, 1.38600e+03,
#          1.52900e+03, 1.63900e+03, 2.16300e+03, 2.19900e+03, 2.55600e+03,
#          2.85500e+03, 2.76800e+03, 2.86000e+03, 2.50400e+03, 2.33900e+03,
#          2.37100e+03, 2.26800e+03, 2.87200e+03, 2.25400e+03, 2.25200e+03,
#          2.34900e+03, 2.29900e+03, 2.46900e+03, 2.74500e+03, 6.21900e+03,
# ...

# %%
image_thres = image_gray < 100
plt.figure(2)
plt.imshow(image_thres,'gray')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
image_edge = cv2.Canny(image_gray,100,255)
plt.figure(3)
plt.imshow(image_edge,'gray')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
