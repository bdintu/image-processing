# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %%
img_path = 'tv.jpg'

# %%
img = cv2.imread(img_path)
img_resize = cv2.resize(img,(img.shape[1]//2,img.shape[0]//2))
img_rgb = cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB)

print('shape', img_rgb.shape)
print('dtype', img_rgb.dtype)

plt.imshow(img_rgb)
# Out:
# shape (180, 240, 3)
# dtype uint8

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

xs = np.ravel(img_rgb[:,:,0])
ys = np.ravel(img_rgb[:,:,1])
zs = np.ravel(img_rgb[:,:,2])
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
ax.scatter(xs, ys, zs)

ax.set_xlabel('R Label')
ax.set_ylabel('G Label')
ax.set_zlabel('B Label')

print(1)
# Out:
# 1
